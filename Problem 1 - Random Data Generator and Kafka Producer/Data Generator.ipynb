# %% [markdown]
# # Problem 1: Random Data Generator and Kafka Producer
# Explanation:
# The goal here is to simulate user interaction data and send it to a Kafka topic for further processing.
# We chose Python for its rich libraries and Kafka for its ability to handle high-throughput data streams. The data generator produces random events with attributes such as user_id, item_id, interaction_type, and timestamp. A Kafka producer then sends these events to a Kafka topic named user_interactions.

# %%
from kafka import KafkaProducer
import json
import random
import time
from datetime import datetime

# Kafka Producer configuration
producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

def generate_random_data():
    return {
        "user_id": random.randint(1, 1000),
        "item_id": random.randint(1, 500),
        "interaction_type": random.choice(["click", "view", "purchase"]),
        "timestamp": datetime.now().isoformat()
    }

# Generate data and send to Kafka topic
while True:
    data = generate_random_data()
    producer.send('user_interactions', value=data)
    print(f"Sent: {data}")
    time.sleep(1)  # Control the rate of data generation
# Out:
# Sent: {'user_id': 461, 'item_id': 82, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:37:59.334688'}
# Sent: {'user_id': 461, 'item_id': 82, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:37:59.334688'}
# Sent: {'user_id': 168, 'item_id': 2, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:38:00.385008'}
# Sent: {'user_id': 168, 'item_id': 2, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:38:00.385008'}
# Sent: {'user_id': 193, 'item_id': 302, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:38:01.397083'}
# Sent: {'user_id': 193, 'item_id': 302, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:38:01.397083'}
# Sent: {'user_id': 740, 'item_id': 53, 'interaction_type': 'view', 'timestamp': '2024-12-07T14:38:02.409069'}
# Sent: {'user_id': 740, 'item_id': 53, 'interaction_type': 'view', 'timestamp': '2024-12-07T14:38:02.409069'}
# ...
