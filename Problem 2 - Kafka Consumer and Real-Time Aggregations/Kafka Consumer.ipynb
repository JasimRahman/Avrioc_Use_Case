# %% [markdown]
# # Problem 2: Kafka Consumer and Real-Time Aggregations
# Explanation:
# This part focuses on consuming messages from Kafka, performing real-time aggregations, and storing the results in a NoSQL database.
# We used MongoDB for its ease of use, scalability, and compatibility with Python. The Kafka consumer reads data, calculates metrics like average interactions per user, and updates the MongoDB collection.

# %%
from kafka import KafkaConsumer
import json
from pymongo import MongoClient

# MongoDB Configuration
client = MongoClient('localhost', 27017)
db = client['user_data']
collection = db['aggregations']

# Kafka Consumer configuration
consumer = KafkaConsumer(
    'user_interactions',
    bootstrap_servers='localhost:9092',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

user_interactions = {}

for message in consumer:
    data = message.value
    user_id = data['user_id']
    item_id = data['item_id']

    # Update user interactions
    if user_id not in user_interactions:
        user_interactions[user_id] = 0
    user_interactions[user_id] += 1

    # Calculate average interactions per user
    avg_interactions = sum(user_interactions.values()) / len(user_interactions)

    # Store data in MongoDB
    collection.update_one(
        {"user_id": user_id},
        {"$set": {"average_interactions": avg_interactions}},
        upsert=True
    )

    print(f"Processed: {data}, Updated Avg: {avg_interactions}")
# Out:
# Processed: {'user_id': 984, 'item_id': 428, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:49:29.282808'}, Updated Avg: 1.0
# Processed: {'user_id': 469, 'item_id': 83, 'interaction_type': 'click', 'timestamp': '2024-12-07T14:49:30.292672'}, Updated Avg: 1.0
# Processed: {'user_id': 576, 'item_id': 376, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:49:31.301429'}, Updated Avg: 1.0
# Processed: {'user_id': 820, 'item_id': 490, 'interaction_type': 'view', 'timestamp': '2024-12-07T14:49:32.311118'}, Updated Avg: 1.0
# Processed: {'user_id': 244, 'item_id': 387, 'interaction_type': 'view', 'timestamp': '2024-12-07T14:49:33.325913'}, Updated Avg: 1.0
# Processed: {'user_id': 783, 'item_id': 283, 'interaction_type': 'click', 'timestamp': '2024-12-07T14:49:34.336814'}, Updated Avg: 1.0
# Processed: {'user_id': 793, 'item_id': 176, 'interaction_type': 'purchase', 'timestamp': '2024-12-07T14:49:35.349121'}, Updated Avg: 1.0
# ...
